# %% [markdown]
# <a href="https://colab.research.google.com/github/unknown96969/elevate/blob/main/syntax_error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/OTTs-Movie&Shows.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 show_id   type                 title        director  \
# 0           0      s1  Movie   The Grand Seduction    Don McKellar
# 1           1      s2  Movie  Take Care Good Night    Girish Joshi
# 2           2      s3  Movie  Secrets of Deception     Josh Webber
# 3           3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4           4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  release_year
# count  22998.000000  22998.000000
# mean   11498.500000   2010.811244
# std     6639.095081     15.401142
# min        0.000000   1920.000000
# 25%     5749.250000   2010.000000
# 50%    11498.500000   2016.000000
# 75%    17247.750000   2019.000000
# max    22997.000000   2021.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_15, *['Unnamed: 0'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
# ...

# %%
df.rename(columns={'Unnamed:0':'listed_in'},inplace=True)

# %%
df.rename(columns=lambda x: x.replace(".","_"),inplace=True)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'show_id', 'type', 'title', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in',
#        'description', 'platform'],
#       dtype='object')

# %%
import seaborn as sns
